# %%
import pandas as pd 
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Damian. K. Matthews\\Desktop\\Python Programming Course'

# %%
movies = pd.read_csv("P4-Movie-Ratings.csv")

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = (['Film', 'Genre', 'CriticRating', 
                   'AudienceRatings',
       'BudgetMillions', 'Year'])

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer      Comedy            87               81
# 1            10,000 B.C.  Adventure             9               44
# 2             12 Rounds      Action            30               52
# 3              127 Hours  Adventure            93               84
# 4              17 Again      Comedy            55               70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    object
#  1   Genre            559 non-null    object
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings  BudgetMillions         Year
# count    559.000000       559.000000      559.000000   559.000000
# mean      47.309481        58.744186       50.236136  2009.152057
# std       26.413091        16.826887       48.731817     1.362632
# min        0.000000         0.000000        0.000000  2007.000000
# 25%       25.000000        47.000000       20.000000  2008.000000
# 50%       46.000000        58.000000       35.000000  2009.000000
# 75%       70.000000        72.000000       65.000000  2010.000000
# max       97.000000        96.000000      300.000000  2011.000000

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    object
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings  BudgetMillions
# count    559.000000       559.000000      559.000000
# mean      47.309481        58.744186       50.236136
# std       26.413091        16.826887       48.731817
# min        0.000000         0.000000        0.000000
# 25%       25.000000        47.000000       20.000000
# 50%       46.000000        58.000000       35.000000
# 75%       70.000000        72.000000       65.000000
# max       97.000000        96.000000      300.000000

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Jointplots

# %%
j = sns.jointplot(data=movies, x="CriticRating", y="AudienceRatings")

# %%
j = sns.jointplot(data=movies, x="CriticRating", y="AudienceRatings",kind='hex')

# %%
#Chart 1

# %%
#Histograms
sns.set_style("darkgrid")
m1 = sns.distplot(movies.AudienceRatings, bins=15)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set_style("darkgrid")
n1 = plt.hist(movies.AudienceRatings, bins=15)

# %%
sns.set_style("dark")
n1 = plt.hist(movies.CriticRating, bins=15)

# %%
#Stacked Histograms

# %%
plt.hist(movies[movies.Genre == 'Action'].BudgetMillions, bins = 15)
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions, bins = 15)
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions, bins = 15)
plt.show()

# %%
m = [movies[movies.Genre == 'Drama'].BudgetMillions, 
 movies[movies.Genre == 'Action'].BudgetMillions]

plt.hist([movies[movies.Genre == 'Action'].BudgetMillions,movies[movies.Genre == 'Drama'].BudgetMillions])
plt.show()

# %%
plt.hist(m, stacked = True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list1 = list()
mylabels = list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillions)
    mylabels.append(gen)

h = plt.hist(list1, bins=30,stacked=True, rwidth=1,label=mylabels)
plt.legend()
plt.show()

# %%
#Chart 4

# %%
vis1 = sns.lmplot(data = movies, x='CriticRating', y='AudienceRatings',
                 fit_reg=False, hue='Genre', height =5.5)

# %%
k1 = sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRatings, 
                shade=True, thresh=0.05, cmap = 'Reds')
# plt.show()

# %%
k1b = sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRatings, 
                 cmap = 'Reds')
# plt.show()

# %%
sns.set_style("dark")
k1 = sns.kdeplot(x= movies.BudgetMillions, y= movies.AudienceRatings)

# %%
sns.set_style("dark")
k2 = sns.kdeplot(x= movies.BudgetMillions, y= movies.CriticRating)

# %%
f, axes=plt.subplots(1,2, figsize =(12,6))
k1 = sns.kdeplot(x= movies.BudgetMillions, y= movies.AudienceRatings, ax=axes[0])
k2 = sns.kdeplot(x= movies.BudgetMillions, y= movies.CriticRating, ax=axes[1])

# %%
f, axes=plt.subplots(2,2, figsize =(12,6))
k1 = sns.kdeplot(x= movies.BudgetMillions, y= movies.AudienceRatings, ax=axes[1,1])
k2 = sns.kdeplot(x= movies.BudgetMillions, y= movies.CriticRating, ax=axes[1,0])

# %%
f, axes=plt.subplots(1,2, figsize =(12,6), sharex=True, sharey=True)
k1 = sns.kdeplot(x= movies.BudgetMillions, y= movies.AudienceRatings, ax=axes[0])
k2 = sns.kdeplot(x= movies.BudgetMillions, y= movies.CriticRating, ax=axes[1])
k1.set(xlim=(-40,230))
# Out:
# [(-40.0, 230.0)]

# %%
#ViolinPlots

# %%
w = sns.boxplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRating')

# %%
w = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRating')

# %%
#Creating a facet grid

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRatings')

# %%
#Can populate with any type of chart. Example: histograms

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
g = g.map(plt.hist, 'BudgetMillions')

# %%
#Back to the scatterplot
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
kws = dict(s=50, linewidth=0.5, edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRatings', **kws)

# %%
#Cotrolling Axes and Adding Diagonals
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
kws = dict(s=50, linewidth=0.5, edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRatings', **kws)
g.set(xlim=(0,100), ylim=(0,100))
for ax in g.axes.flat:
    ax.plot((0,100),(0,100), c='gray', ls='--')
g.add_legend()

# %%
#Chart 5

# %%
#Building Dashboards

# %%
sns.set_style("darkgrid")
f, axes = plt.subplots(2,2, figsize = (15,15))
k1 = sns.kdeplot(x= movies.BudgetMillions, y= movies.AudienceRatings,\
                 ax=axes[0,0])
k2 = sns.kdeplot(x= movies.BudgetMillions, y= movies.CriticRating,\
                 ax=axes[0,1])
w = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', \
                   y='CriticRating', ax=axes[1,0])
k4 = sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRatings, \
                 cmap = 'Reds', ax = axes[1,1])
k3 = sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRatings, \
                shade=True, thresh=0.05, cmap = 'Reds', ax=axes[1,1])
# ax=axes[1,1].hist(movies.CriticRating, bins=15)
k1.set(xlim=(-40,230))
k2.set(xlim=(-40,230))
plt.show()

# %%
#Styling dashboard

# %%
    sns.set_style("dark", {"axes.facecolor":"black"})
f, axes = plt.subplots(2,2, figsize = (15,15))
#Plot [0,0]
k1 = sns.kdeplot(x= movies.BudgetMillions, y= movies.AudienceRatings,\
                cmap='cool',\
                 ax=axes[0,0])
# Give an outline to plot [0,0]
k1 = sns.kdeplot(x= movies.BudgetMillions, y= movies.AudienceRatings,\
                 shade=True, thresh = 0, cmap='inferno',\
                 ax=axes[0,0])

#Plot [0,1]
k2 = sns.kdeplot(x= movies.BudgetMillions, y= movies.CriticRating,\
                 shade=True, thresh = 0, cmap='inferno',
                 ax=axes[0,1])
# Plot[0,1] outline
k2 = sns.kdeplot(x= movies.BudgetMillions, y= movies.CriticRating,\
                 cmap='cool', ax=axes[0,1])

#Plot [1,0]
w = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', \
                   y='CriticRating', ax=axes[1,0],\
                  palette='YlOrRd')
#Plot [1,1]
k4 = sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRatings, \
                 cmap = 'gist_gray_r', ax = axes[1,1])
k3 = sns.kdeplot(x=movies.CriticRating, y=movies.AudienceRatings, \
                shade=True, thresh=0, cmap ='Blues_r', ax=axes[1,1])
# ax=axes[1,1].hist(movies.CriticRating, bins=15)
k1.set(xlim=(-40,230))
k2.set(xlim=(-40,230))
plt.show()

# %%
# Thematic Edits
list1 = list()
mylabels = list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillions)
    mylabels.append(gen)

sns.set_style("whitegrid")
fig, ax = plt.subplots()
fig.set_size_inches(11.7,8.27)
plt.hist(list1, bins=30,stacked=True, rwidth=1,label=mylabels)
plt.title("Movie Budget", fontsize=35, \
         color="DarkBlue", fontname = "Console")
plt.ylabel("Number of movies", fontsize=25, color = 'Red')
plt.xlabel("Budget", fontsize=25, color = 'Green')
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.legend(prop={'size':20}, shadow=True)
plt.show()
